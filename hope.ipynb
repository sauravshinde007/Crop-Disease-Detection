# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
from efficientnet_pytorch import EfficientNet
from torch.utils.data import DataLoader
from torchvision import datasets
# from torch.cuda.amp import autocast, GradScaler
import json
from PIL import Image
from torchsummary import summary


# Add CBAM (Channel & Spatial Attention)
class CBAMLayer(nn.Module):
    def __init__(self, in_channels):
        super(CBAMLayer, self).__init__()
        self.conv = nn.Conv2d(in_channels, in_channels, kernel_size=1)
    
    def forward(self, x):
        attention = torch.sigmoid(self.conv(x))
        return x * attention

# %%
# Base EfficientNet architecture details
base_model = [
    [1, 16, 1, 1, 3],
    [6, 24, 2, 2, 3],
    [6, 40, 2, 2, 5],
    [6, 80, 3, 2, 3],
    [6, 112, 3, 1, 5],
    [6, 192, 4, 2, 5],
    [6, 320, 1, 1, 3],
]

phi_values = {
    "b0": (0, 224, 0.2),
    "b1": (0.5, 240, 0.2),
    "b2": (1, 260, 0.3),
    "b3": (2, 300, 0.3),
    "b4": (3, 380, 0.4),
    "b5": (4, 456, 0.4),
    "b6": (5, 528, 0.5),
    "b7": (6, 600, 0.5),
}

# %%
# Device Setup (GPU if available)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

version = "b3" #efficientnet version

# Data Preprocessing and Augmentation
transform = transforms.Compose([
    transforms.Resize((phi_values[version][1], phi_values[version][1])),  # Resize images to fit the model's input size
    transforms.ToTensor(),  # Convert images to tensor
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])  # Normalize images
])

# Load datasets (assuming you have train and test data in 'Processed_Data/train' and 'Processed_Data/test')
train_dataset = datasets.ImageFolder(root="Processed_Data/train", transform=transform)
test_dataset = datasets.ImageFolder(root="Processed_Data/test", transform=transform)

# DataLoader Setup
batch_size = 32  # Adjust batch size as needed
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True,num_workers=4)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=4)

# Save class names for inference
with open("class_names.json", "w") as f:
    json.dump(train_dataset.classes, f)


# Load Pretrained EfficientNet Model
model = EfficientNet.from_pretrained('efficientnet-b3')


# Modify Final Layer for the Number of Classes in Your Dataset
num_ftrs = model._fc.in_features
print(len(train_dataset.classes))
model._fc = nn.Linear(num_ftrs, len(train_dataset.classes))  # Adjust the number of classes

model.cbam = CBAMLayer(in_channels=num_ftrs)
# Move model to GPU if available
model = model.to(device)

# Loss Function and Optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.0001)

# Learning Rate Scheduler
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', patience=1, factor=0.1, verbose=True)

# Early Stopping Parameters
patience = 2  # Stop if validation loss doesn't improve for 'patience' epochs
best_val_loss = float('inf')
epochs_no_improve = 0

# Mixed Precision Training (FP16)
scaler = torch.amp.GradScaler('cuda')

def validate_model(model, test_loader):
    model.eval()
    val_loss = 0.0
    correct = 0
    total = 0

    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            with torch.amp.autocast('cuda'):
                outputs = model(images)
                loss = criterion(outputs, labels)
            val_loss += loss.item()

            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    avg_loss = val_loss / len(test_loader)
    accuracy = 100 * correct / total
    return avg_loss, accuracy

# Training Function with Early Stopping
def train_model(model, train_loader, num_epochs):

    global best_val_loss, epochs_no_improve

    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0

        for i,(images, labels) in enumerate(train_loader):
            images, labels = images.to(device), labels.to(device)

            optimizer.zero_grad()

            with torch.amp.autocast('cuda'):  # FP16 forward pass
                outputs = model(images)
                loss = criterion(outputs, labels)

            # Backpropagation with scaler
            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()

            running_loss += loss.item()
            if i % 10 == 0:  # Print more frequently
                    print(f"Epoch [{epoch + 1}/{num_epochs}], Batch [{i}/{len(train_loader)}], Loss: {loss.item():.4f}")

        avg_loss = running_loss / len(train_loader)
        val_loss, val_acc = validate_model(model, test_loader)
        print(f"Epoch [{epoch+1}/{num_epochs}], Train Loss: {avg_loss:.4f}, Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.2f}%")

        scheduler.step(val_loss)  # Adjust learning rate if validation loss plateaus

        # Check for Early Stopping
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            epochs_no_improve = 0
            torch.save(model.state_dict(), 'crop_disease_model.pth')  # Save the best model
            print("✅ Model saved (new best validation loss)")
        else:
            epochs_no_improve += 1
            print(f"⚠️ No improvement in validation loss for {epochs_no_improve} epoch(s)")

        if epochs_no_improve >= patience:
            print(f"🚀 Early stopping at epoch {epoch+1}. Best Validation Loss: {best_val_loss:.4f}")
            break


# Train the Model
# train_model(model, train_loader, num_epochs=3)
# Out:
# Loaded pretrained weights for efficientnet-b3
# 22

# %%
# # Load class names from JSON file
# with open("class_names.json", "r") as file:
#     class_names = json.load(file)  # Should be a list of class names


# # Load saved modael weights
# model.load_state_dict(torch.load("crop_disease_model.pth", map_location=device))
# model.to(device)
# model.eval()
    
# # Predict on a sample image
# image_path = "Processed_Data/test/Tomato_healthy/healthy2_.jpg"  # Replace with your image path
# predicted_disease, confidence = predict_image(image_path, model, class_names)

# print(f"Predicted Disease: {predicted_disease} (Confidence: {confidence:.2f})")

# %%
#Clearing cache

# import torch
# import gc

# torch.cuda.empty_cache()  # Clears unused memory from the cache
# torch.cuda.ipc_collect()
# gc.collect()  # Force garbage collection
# torch.cuda.empty_cache()

# %%
import torch
import json
from torchvision import transforms
from PIL import Image

# ==========================
# PREDICTION FUNCTION (CROP-SPECIFIC)
# ==========================
def predict(image_path, crop_name, model, device):
    """
    Predicts the disease of the given image, considering only diseases from the specified crop.
    
    :param image_path: Path to the image file
    :param crop_name: The crop to filter diseases from (e.g., "Cashew")
    :param model: The trained model
    :param device: The device (CPU/GPU) for computation
    :return: Predicted crop name, disease name, and confidence score
    """

    # Define image transformations (same as training)
    transform = transforms.Compose([
        transforms.Resize((300, 300)),  # Resize to EfficientNet-B3 input size
        transforms.ToTensor(),          # Convert image to tensor
        transforms.Normalize(           # Normalize using ImageNet stats
            mean=[0.485, 0.456, 0.406], 
            std=[0.229, 0.224, 0.225]
        )
    ])

    # Load and preprocess the image
    try:
        image = Image.open(image_path).convert("RGB")
    except Exception as e:
        raise ValueError(f"Error loading image: {e}")

    image = transform(image).unsqueeze(0)  # Add batch dimension
    image = image.to(device)

    # Move model to device
    model = model.to(device)
    model.eval()

    # Load class names
    with open("class_names.json", "r") as f:
        class_names = json.load(f)

    # Filter disease classes for the given crop
    crop_classes = [cls for cls in class_names if cls.startswith(crop_name)]
    if not crop_classes:
        raise ValueError(f"No diseases found for crop: {crop_name}")

    # Create index mapping for this crop
    crop_indices = [class_names.index(cls) for cls in crop_classes]

    # Run inference
    with torch.no_grad():
        output = model(image)

    # Extract relevant disease classes
    crop_output = output[:, crop_indices]  # Select only disease indices related to crop
    predicted_idx = torch.argmax(crop_output, dim=1).item()

    # Map back to disease name
    predicted_disease = crop_classes[predicted_idx]
    confidence = torch.nn.functional.softmax(crop_output, dim=1)[0][predicted_idx].item()

    # Extract only the disease name (removing crop prefix)
    disease_name = predicted_disease.split("_", 1)[1]

    print(f"✅ Predicted Crop: {crop_name}")
    print(f"✅ Predicted Disease: {disease_name} (Confidence: {confidence:.2f})")

    return crop_name, disease_name, confidence

# ==========================
# SAMPLE PREDICTION
# ==========================

# Define device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Load the model
model.load_state_dict(torch.load("crop_disease_model.pth", map_location=device))
model.to(device)
model.eval()

# Define crop and image path
crop_name = "Tomato"  # Example crop input
image_path = "Sample Predict/tomato_leafblight.jpg"

# Run prediction
predict(image_path, crop_name, model, device)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_20912\3009905370.py:83: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load("crop_disease_model.pth", map_location=device))
# ✅ Predicted Crop: Tomato
# ✅ Predicted Disease: leaf curl (Confidence: 0.74)
# ('Tomato', 'leaf curl', 0.7434619069099426)

# %%
# Print Model Summary
summary(model, input_size=(3, 300, 300))  # Adjust input size based on EfficientNet-B3
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#          ZeroPad2d-1          [-1, 3, 301, 301]               0
# Conv2dStaticSamePadding-2         [-1, 40, 150, 150]           1,080
#        BatchNorm2d-3         [-1, 40, 150, 150]              80
# MemoryEfficientSwish-4         [-1, 40, 150, 150]               0
#          ZeroPad2d-5         [-1, 40, 152, 152]               0
# Conv2dStaticSamePadding-6         [-1, 40, 150, 150]             360
#        BatchNorm2d-7         [-1, 40, 150, 150]              80
# MemoryEfficientSwish-8         [-1, 40, 150, 150]               0
#           Identity-9             [-1, 40, 1, 1]               0
# Conv2dStaticSamePadding-10             [-1, 10, 1, 1]             410
# MemoryEfficientSwish-11             [-1, 10, 1, 1]               0
#          Identity-12             [-1, 10, 1, 1]               0
# Conv2dStaticSamePadding-13             [-1, 40, 1, 1]             440
#          Identity-14         [-1, 40, 150, 150]               0
# Conv2dStaticSamePadding-15         [-1, 24, 150, 150]             960
#       BatchNorm2d-16         [-1, 24, 150, 150]              48
#       MBConvBlock-17         [-1, 24, 150, 150]               0
#         ZeroPad2d-18         [-1, 24, 152, 152]               0
# Conv2dStaticSamePadding-19         [-1, 24, 150, 150]             216
#       BatchNorm2d-20         [-1, 24, 150, 150]              48
# MemoryEfficientSwish-21         [-1, 24, 150, 150]               0
#          Identity-22             [-1, 24, 1, 1]               0
# Conv2dStaticSamePadding-23              [-1, 6, 1, 1]             150
# MemoryEfficientSwish-24              [-1, 6, 1, 1]               0
#          Identity-25              [-1, 6, 1, 1]               0
# Conv2dStaticSamePadding-26             [-1, 24, 1, 1]             168
#          Identity-27         [-1, 24, 150, 150]               0
# Conv2dStaticSamePadding-28         [-1, 24, 150, 150]             576
#       BatchNorm2d-29         [-1, 24, 150, 150]              48
#       MBConvBlock-30         [-1, 24, 150, 150]               0
#          Identity-31         [-1, 24, 150, 150]               0
# Conv2dStaticSamePadding-32        [-1, 144, 150, 150]           3,456
#       BatchNorm2d-33        [-1, 144, 150, 150]             288
# MemoryEfficientSwish-34        [-1, 144, 150, 150]               0
#         ZeroPad2d-35        [-1, 144, 151, 151]               0
# Conv2dStaticSamePadding-36          [-1, 144, 75, 75]           1,296
#       BatchNorm2d-37          [-1, 144, 75, 75]             288
# MemoryEfficientSwish-38          [-1, 144, 75, 75]               0
#          Identity-39            [-1, 144, 1, 1]               0
# Conv2dStaticSamePadding-40              [-1, 6, 1, 1]             870
# MemoryEfficientSwish-41              [-1, 6, 1, 1]               0
#          Identity-42              [-1, 6, 1, 1]               0
# Conv2dStaticSamePadding-43            [-1, 144, 1, 1]           1,008
#          Identity-44          [-1, 144, 75, 75]               0
# Conv2dStaticSamePadding-45           [-1, 32, 75, 75]           4,608
#       BatchNorm2d-46           [-1, 32, 75, 75]              64
#       MBConvBlock-47           [-1, 32, 75, 75]               0
#          Identity-48           [-1, 32, 75, 75]               0
# Conv2dStaticSamePadding-49          [-1, 192, 75, 75]           6,144
#       BatchNorm2d-50          [-1, 192, 75, 75]             384
# MemoryEfficientSwish-51          [-1, 192, 75, 75]               0
#         ZeroPad2d-52          [-1, 192, 77, 77]               0
# Conv2dStaticSamePadding-53          [-1, 192, 75, 75]           1,728
#       BatchNorm2d-54          [-1, 192, 75, 75]             384
# MemoryEfficientSwish-55          [-1, 192, 75, 75]               0
#          Identity-56            [-1, 192, 1, 1]               0
# Conv2dStaticSamePadding-57              [-1, 8, 1, 1]           1,544
# MemoryEfficientSwish-58              [-1, 8, 1, 1]               0
#          Identity-59              [-1, 8, 1, 1]               0
# Conv2dStaticSamePadding-60            [-1, 192, 1, 1]           1,728
#          Identity-61          [-1, 192, 75, 75]               0
# Conv2dStaticSamePadding-62           [-1, 32, 75, 75]           6,144
#       BatchNorm2d-63           [-1, 32, 75, 75]              64
#       MBConvBlock-64           [-1, 32, 75, 75]               0
#          Identity-65           [-1, 32, 75, 75]               0
# Conv2dStaticSamePadding-66          [-1, 192, 75, 75]           6,144
#       BatchNorm2d-67          [-1, 192, 75, 75]             384
# MemoryEfficientSwish-68          [-1, 192, 75, 75]               0
#         ZeroPad2d-69          [-1, 192, 77, 77]               0
# Conv2dStaticSamePadding-70          [-1, 192, 75, 75]           1,728
#       BatchNorm2d-71          [-1, 192, 75, 75]             384
# MemoryEfficientSwish-72          [-1, 192, 75, 75]               0
#          Identity-73            [-1, 192, 1, 1]               0
# Conv2dStaticSamePadding-74              [-1, 8, 1, 1]           1,544
# MemoryEfficientSwish-75              [-1, 8, 1, 1]               0
#          Identity-76              [-1, 8, 1, 1]               0
# Conv2dStaticSamePadding-77            [-1, 192, 1, 1]           1,728
#          Identity-78          [-1, 192, 75, 75]               0
# Conv2dStaticSamePadding-79           [-1, 32, 75, 75]           6,144
#       BatchNorm2d-80           [-1, 32, 75, 75]              64
#       MBConvBlock-81           [-1, 32, 75, 75]               0
#          Identity-82           [-1, 32, 75, 75]               0
# Conv2dStaticSamePadding-83          [-1, 192, 75, 75]           6,144
#       BatchNorm2d-84          [-1, 192, 75, 75]             384
# MemoryEfficientSwish-85          [-1, 192, 75, 75]               0
#         ZeroPad2d-86          [-1, 192, 79, 79]               0
# Conv2dStaticSamePadding-87          [-1, 192, 38, 38]           4,800
#       BatchNorm2d-88          [-1, 192, 38, 38]             384
# MemoryEfficientSwish-89          [-1, 192, 38, 38]               0
#          Identity-90            [-1, 192, 1, 1]               0
# Conv2dStaticSamePadding-91              [-1, 8, 1, 1]           1,544
# MemoryEfficientSwish-92              [-1, 8, 1, 1]               0
#          Identity-93              [-1, 8, 1, 1]               0
# Conv2dStaticSamePadding-94            [-1, 192, 1, 1]           1,728
#          Identity-95          [-1, 192, 38, 38]               0
# Conv2dStaticSamePadding-96           [-1, 48, 38, 38]           9,216
#       BatchNorm2d-97           [-1, 48, 38, 38]              96
#       MBConvBlock-98           [-1, 48, 38, 38]               0
#          Identity-99           [-1, 48, 38, 38]               0
# Conv2dStaticSamePadding-100          [-1, 288, 38, 38]          13,824
#      BatchNorm2d-101          [-1, 288, 38, 38]             576
# MemoryEfficientSwish-102          [-1, 288, 38, 38]               0
#        ZeroPad2d-103          [-1, 288, 42, 42]               0
# Conv2dStaticSamePadding-104          [-1, 288, 38, 38]           7,200
#      BatchNorm2d-105          [-1, 288, 38, 38]             576
# MemoryEfficientSwish-106          [-1, 288, 38, 38]               0
#         Identity-107            [-1, 288, 1, 1]               0
# Conv2dStaticSamePadding-108             [-1, 12, 1, 1]           3,468
# MemoryEfficientSwish-109             [-1, 12, 1, 1]               0
#         Identity-110             [-1, 12, 1, 1]               0
# Conv2dStaticSamePadding-111            [-1, 288, 1, 1]           3,744
#         Identity-112          [-1, 288, 38, 38]               0
# Conv2dStaticSamePadding-113           [-1, 48, 38, 38]          13,824
#      BatchNorm2d-114           [-1, 48, 38, 38]              96
#      MBConvBlock-115           [-1, 48, 38, 38]               0
#         Identity-116           [-1, 48, 38, 38]               0
# Conv2dStaticSamePadding-117          [-1, 288, 38, 38]          13,824
#      BatchNorm2d-118          [-1, 288, 38, 38]             576
# MemoryEfficientSwish-119          [-1, 288, 38, 38]               0
#        ZeroPad2d-120          [-1, 288, 42, 42]               0
# Conv2dStaticSamePadding-121          [-1, 288, 38, 38]           7,200
#      BatchNorm2d-122          [-1, 288, 38, 38]             576
# MemoryEfficientSwish-123          [-1, 288, 38, 38]               0
#         Identity-124            [-1, 288, 1, 1]               0
# Conv2dStaticSamePadding-125             [-1, 12, 1, 1]           3,468
# MemoryEfficientSwish-126             [-1, 12, 1, 1]               0
#         Identity-127             [-1, 12, 1, 1]               0
# Conv2dStaticSamePadding-128            [-1, 288, 1, 1]           3,744
#         Identity-129          [-1, 288, 38, 38]               0
# Conv2dStaticSamePadding-130           [-1, 48, 38, 38]          13,824
#      BatchNorm2d-131           [-1, 48, 38, 38]              96
#      MBConvBlock-132           [-1, 48, 38, 38]               0
#         Identity-133           [-1, 48, 38, 38]               0
# Conv2dStaticSamePadding-134          [-1, 288, 38, 38]          13,824
#      BatchNorm2d-135          [-1, 288, 38, 38]             576
# MemoryEfficientSwish-136          [-1, 288, 38, 38]               0
#        ZeroPad2d-137          [-1, 288, 39, 39]               0
# Conv2dStaticSamePadding-138          [-1, 288, 19, 19]           2,592
#      BatchNorm2d-139          [-1, 288, 19, 19]             576
# MemoryEfficientSwish-140          [-1, 288, 19, 19]               0
#         Identity-141            [-1, 288, 1, 1]               0
# Conv2dStaticSamePadding-142             [-1, 12, 1, 1]           3,468
# MemoryEfficientSwish-143             [-1, 12, 1, 1]               0
#         Identity-144             [-1, 12, 1, 1]               0
# Conv2dStaticSamePadding-145            [-1, 288, 1, 1]           3,744
#         Identity-146          [-1, 288, 19, 19]               0
# Conv2dStaticSamePadding-147           [-1, 96, 19, 19]          27,648
#      BatchNorm2d-148           [-1, 96, 19, 19]             192
#      MBConvBlock-149           [-1, 96, 19, 19]               0
#         Identity-150           [-1, 96, 19, 19]               0
# Conv2dStaticSamePadding-151          [-1, 576, 19, 19]          55,296
#      BatchNorm2d-152          [-1, 576, 19, 19]           1,152
# MemoryEfficientSwish-153          [-1, 576, 19, 19]               0
#        ZeroPad2d-154          [-1, 576, 21, 21]               0
# Conv2dStaticSamePadding-155          [-1, 576, 19, 19]           5,184
#      BatchNorm2d-156          [-1, 576, 19, 19]           1,152
# MemoryEfficientSwish-157          [-1, 576, 19, 19]               0
#         Identity-158            [-1, 576, 1, 1]               0
# Conv2dStaticSamePadding-159             [-1, 24, 1, 1]          13,848
# MemoryEfficientSwish-160             [-1, 24, 1, 1]               0
#         Identity-161             [-1, 24, 1, 1]               0
# Conv2dStaticSamePadding-162            [-1, 576, 1, 1]          14,400
#         Identity-163          [-1, 576, 19, 19]               0
# Conv2dStaticSamePadding-164           [-1, 96, 19, 19]          55,296
#      BatchNorm2d-165           [-1, 96, 19, 19]             192
#      MBConvBlock-166           [-1, 96, 19, 19]               0
#         Identity-167           [-1, 96, 19, 19]               0
# Conv2dStaticSamePadding-168          [-1, 576, 19, 19]          55,296
#      BatchNorm2d-169          [-1, 576, 19, 19]           1,152
# MemoryEfficientSwish-170          [-1, 576, 19, 19]               0
#        ZeroPad2d-171          [-1, 576, 21, 21]               0
# Conv2dStaticSamePadding-172          [-1, 576, 19, 19]           5,184
#      BatchNorm2d-173          [-1, 576, 19, 19]           1,152
# MemoryEfficientSwish-174          [-1, 576, 19, 19]               0
#         Identity-175            [-1, 576, 1, 1]               0
# Conv2dStaticSamePadding-176             [-1, 24, 1, 1]          13,848
# MemoryEfficientSwish-177             [-1, 24, 1, 1]               0
#         Identity-178             [-1, 24, 1, 1]               0
# Conv2dStaticSamePadding-179            [-1, 576, 1, 1]          14,400
#         Identity-180          [-1, 576, 19, 19]               0
# Conv2dStaticSamePadding-181           [-1, 96, 19, 19]          55,296
#      BatchNorm2d-182           [-1, 96, 19, 19]             192
#      MBConvBlock-183           [-1, 96, 19, 19]               0
#         Identity-184           [-1, 96, 19, 19]               0
# Conv2dStaticSamePadding-185          [-1, 576, 19, 19]          55,296
#      BatchNorm2d-186          [-1, 576, 19, 19]           1,152
# MemoryEfficientSwish-187          [-1, 576, 19, 19]               0
#        ZeroPad2d-188          [-1, 576, 21, 21]               0
# Conv2dStaticSamePadding-189          [-1, 576, 19, 19]           5,184
#      BatchNorm2d-190          [-1, 576, 19, 19]           1,152
# MemoryEfficientSwish-191          [-1, 576, 19, 19]               0
#         Identity-192            [-1, 576, 1, 1]               0
# Conv2dStaticSamePadding-193             [-1, 24, 1, 1]          13,848
# MemoryEfficientSwish-194             [-1, 24, 1, 1]               0
#         Identity-195             [-1, 24, 1, 1]               0
# Conv2dStaticSamePadding-196            [-1, 576, 1, 1]          14,400
#         Identity-197          [-1, 576, 19, 19]               0
# Conv2dStaticSamePadding-198           [-1, 96, 19, 19]          55,296
#      BatchNorm2d-199           [-1, 96, 19, 19]             192
#      MBConvBlock-200           [-1, 96, 19, 19]               0
#         Identity-201           [-1, 96, 19, 19]               0
# Conv2dStaticSamePadding-202          [-1, 576, 19, 19]          55,296
#      BatchNorm2d-203          [-1, 576, 19, 19]           1,152
# MemoryEfficientSwish-204          [-1, 576, 19, 19]               0
#        ZeroPad2d-205          [-1, 576, 21, 21]               0
# Conv2dStaticSamePadding-206          [-1, 576, 19, 19]           5,184
#      BatchNorm2d-207          [-1, 576, 19, 19]           1,152
# MemoryEfficientSwish-208          [-1, 576, 19, 19]               0
#         Identity-209            [-1, 576, 1, 1]               0
# Conv2dStaticSamePadding-210             [-1, 24, 1, 1]          13,848
# MemoryEfficientSwish-211             [-1, 24, 1, 1]               0
#         Identity-212             [-1, 24, 1, 1]               0
# Conv2dStaticSamePadding-213            [-1, 576, 1, 1]          14,400
#         Identity-214          [-1, 576, 19, 19]               0
# Conv2dStaticSamePadding-215           [-1, 96, 19, 19]          55,296
#      BatchNorm2d-216           [-1, 96, 19, 19]             192
#      MBConvBlock-217           [-1, 96, 19, 19]               0
#         Identity-218           [-1, 96, 19, 19]               0
# Conv2dStaticSamePadding-219          [-1, 576, 19, 19]          55,296
#      BatchNorm2d-220          [-1, 576, 19, 19]           1,152
# MemoryEfficientSwish-221          [-1, 576, 19, 19]               0
#        ZeroPad2d-222          [-1, 576, 23, 23]               0
# Conv2dStaticSamePadding-223          [-1, 576, 19, 19]          14,400
#      BatchNorm2d-224          [-1, 576, 19, 19]           1,152
# MemoryEfficientSwish-225          [-1, 576, 19, 19]               0
#         Identity-226            [-1, 576, 1, 1]               0
# Conv2dStaticSamePadding-227             [-1, 24, 1, 1]          13,848
# MemoryEfficientSwish-228             [-1, 24, 1, 1]               0
#         Identity-229             [-1, 24, 1, 1]               0
# Conv2dStaticSamePadding-230            [-1, 576, 1, 1]          14,400
#         Identity-231          [-1, 576, 19, 19]               0
# Conv2dStaticSamePadding-232          [-1, 136, 19, 19]          78,336
#      BatchNorm2d-233          [-1, 136, 19, 19]             272
#      MBConvBlock-234          [-1, 136, 19, 19]               0
#         Identity-235          [-1, 136, 19, 19]               0
# Conv2dStaticSamePadding-236          [-1, 816, 19, 19]         110,976
#      BatchNorm2d-237          [-1, 816, 19, 19]           1,632
# MemoryEfficientSwish-238          [-1, 816, 19, 19]               0
#        ZeroPad2d-239          [-1, 816, 23, 23]               0
# Conv2dStaticSamePadding-240          [-1, 816, 19, 19]          20,400
#      BatchNorm2d-241          [-1, 816, 19, 19]           1,632
# MemoryEfficientSwish-242          [-1, 816, 19, 19]               0
#         Identity-243            [-1, 816, 1, 1]               0
# Conv2dStaticSamePadding-244             [-1, 34, 1, 1]          27,778
# MemoryEfficientSwish-245             [-1, 34, 1, 1]               0
#         Identity-246             [-1, 34, 1, 1]               0
# Conv2dStaticSamePadding-247            [-1, 816, 1, 1]          28,560
#         Identity-248          [-1, 816, 19, 19]               0
# Conv2dStaticSamePadding-249          [-1, 136, 19, 19]         110,976
#      BatchNorm2d-250          [-1, 136, 19, 19]             272
#      MBConvBlock-251          [-1, 136, 19, 19]               0
#         Identity-252          [-1, 136, 19, 19]               0
# Conv2dStaticSamePadding-253          [-1, 816, 19, 19]         110,976
#      BatchNorm2d-254          [-1, 816, 19, 19]           1,632
# MemoryEfficientSwish-255          [-1, 816, 19, 19]               0
#        ZeroPad2d-256          [-1, 816, 23, 23]               0
# Conv2dStaticSamePadding-257          [-1, 816, 19, 19]          20,400
#      BatchNorm2d-258          [-1, 816, 19, 19]           1,632
# MemoryEfficientSwish-259          [-1, 816, 19, 19]               0
#         Identity-260            [-1, 816, 1, 1]               0
# Conv2dStaticSamePadding-261             [-1, 34, 1, 1]          27,778
# MemoryEfficientSwish-262             [-1, 34, 1, 1]               0
#         Identity-263             [-1, 34, 1, 1]               0
# Conv2dStaticSamePadding-264            [-1, 816, 1, 1]          28,560
#         Identity-265          [-1, 816, 19, 19]               0
# Conv2dStaticSamePadding-266          [-1, 136, 19, 19]         110,976
#      BatchNorm2d-267          [-1, 136, 19, 19]             272
#      MBConvBlock-268          [-1, 136, 19, 19]               0
#         Identity-269          [-1, 136, 19, 19]               0
# Conv2dStaticSamePadding-270          [-1, 816, 19, 19]         110,976
#      BatchNorm2d-271          [-1, 816, 19, 19]           1,632
# MemoryEfficientSwish-272          [-1, 816, 19, 19]               0
#        ZeroPad2d-273          [-1, 816, 23, 23]               0
# Conv2dStaticSamePadding-274          [-1, 816, 19, 19]          20,400
#      BatchNorm2d-275          [-1, 816, 19, 19]           1,632
# MemoryEfficientSwish-276          [-1, 816, 19, 19]               0
#         Identity-277            [-1, 816, 1, 1]               0
# Conv2dStaticSamePadding-278             [-1, 34, 1, 1]          27,778
# MemoryEfficientSwish-279             [-1, 34, 1, 1]               0
#         Identity-280             [-1, 34, 1, 1]               0
# Conv2dStaticSamePadding-281            [-1, 816, 1, 1]          28,560
#         Identity-282          [-1, 816, 19, 19]               0
# Conv2dStaticSamePadding-283          [-1, 136, 19, 19]         110,976
#      BatchNorm2d-284          [-1, 136, 19, 19]             272
#      MBConvBlock-285          [-1, 136, 19, 19]               0
#         Identity-286          [-1, 136, 19, 19]               0
# Conv2dStaticSamePadding-287          [-1, 816, 19, 19]         110,976
#      BatchNorm2d-288          [-1, 816, 19, 19]           1,632
# MemoryEfficientSwish-289          [-1, 816, 19, 19]               0
#        ZeroPad2d-290          [-1, 816, 23, 23]               0
# Conv2dStaticSamePadding-291          [-1, 816, 19, 19]          20,400
#      BatchNorm2d-292          [-1, 816, 19, 19]           1,632
# MemoryEfficientSwish-293          [-1, 816, 19, 19]               0
#         Identity-294            [-1, 816, 1, 1]               0
# Conv2dStaticSamePadding-295             [-1, 34, 1, 1]          27,778
# MemoryEfficientSwish-296             [-1, 34, 1, 1]               0
#         Identity-297             [-1, 34, 1, 1]               0
# Conv2dStaticSamePadding-298            [-1, 816, 1, 1]          28,560
#         Identity-299          [-1, 816, 19, 19]               0
# Conv2dStaticSamePadding-300          [-1, 136, 19, 19]         110,976
#      BatchNorm2d-301          [-1, 136, 19, 19]             272
#      MBConvBlock-302          [-1, 136, 19, 19]               0
#         Identity-303          [-1, 136, 19, 19]               0
# Conv2dStaticSamePadding-304          [-1, 816, 19, 19]         110,976
#      BatchNorm2d-305          [-1, 816, 19, 19]           1,632
# MemoryEfficientSwish-306          [-1, 816, 19, 19]               0
#        ZeroPad2d-307          [-1, 816, 23, 23]               0
# Conv2dStaticSamePadding-308          [-1, 816, 10, 10]          20,400
#      BatchNorm2d-309          [-1, 816, 10, 10]           1,632
# MemoryEfficientSwish-310          [-1, 816, 10, 10]               0
#         Identity-311            [-1, 816, 1, 1]               0
# Conv2dStaticSamePadding-312             [-1, 34, 1, 1]          27,778
# MemoryEfficientSwish-313             [-1, 34, 1, 1]               0
#         Identity-314             [-1, 34, 1, 1]               0
# Conv2dStaticSamePadding-315            [-1, 816, 1, 1]          28,560
#         Identity-316          [-1, 816, 10, 10]               0
# Conv2dStaticSamePadding-317          [-1, 232, 10, 10]         189,312
#      BatchNorm2d-318          [-1, 232, 10, 10]             464
#      MBConvBlock-319          [-1, 232, 10, 10]               0
#         Identity-320          [-1, 232, 10, 10]               0
# Conv2dStaticSamePadding-321         [-1, 1392, 10, 10]         322,944
#      BatchNorm2d-322         [-1, 1392, 10, 10]           2,784
# MemoryEfficientSwish-323         [-1, 1392, 10, 10]               0
#        ZeroPad2d-324         [-1, 1392, 14, 14]               0
# Conv2dStaticSamePadding-325         [-1, 1392, 10, 10]          34,800
#      BatchNorm2d-326         [-1, 1392, 10, 10]           2,784
# MemoryEfficientSwish-327         [-1, 1392, 10, 10]               0
#         Identity-328           [-1, 1392, 1, 1]               0
# Conv2dStaticSamePadding-329             [-1, 58, 1, 1]          80,794
# MemoryEfficientSwish-330             [-1, 58, 1, 1]               0
#         Identity-331             [-1, 58, 1, 1]               0
# Conv2dStaticSamePadding-332           [-1, 1392, 1, 1]          82,128
#         Identity-333         [-1, 1392, 10, 10]               0
# Conv2dStaticSamePadding-334          [-1, 232, 10, 10]         322,944
#      BatchNorm2d-335          [-1, 232, 10, 10]             464
#      MBConvBlock-336          [-1, 232, 10, 10]               0
#         Identity-337          [-1, 232, 10, 10]               0
# Conv2dStaticSamePadding-338         [-1, 1392, 10, 10]         322,944
#      BatchNorm2d-339         [-1, 1392, 10, 10]           2,784
# MemoryEfficientSwish-340         [-1, 1392, 10, 10]               0
#        ZeroPad2d-341         [-1, 1392, 14, 14]               0
# Conv2dStaticSamePadding-342         [-1, 1392, 10, 10]          34,800
#      BatchNorm2d-343         [-1, 1392, 10, 10]           2,784
# MemoryEfficientSwish-344         [-1, 1392, 10, 10]               0
#         Identity-345           [-1, 1392, 1, 1]               0
# Conv2dStaticSamePadding-346             [-1, 58, 1, 1]          80,794
# MemoryEfficientSwish-347             [-1, 58, 1, 1]               0
#         Identity-348             [-1, 58, 1, 1]               0
# Conv2dStaticSamePadding-349           [-1, 1392, 1, 1]          82,128
#         Identity-350         [-1, 1392, 10, 10]               0
# Conv2dStaticSamePadding-351          [-1, 232, 10, 10]         322,944
#      BatchNorm2d-352          [-1, 232, 10, 10]             464
#      MBConvBlock-353          [-1, 232, 10, 10]               0
#         Identity-354          [-1, 232, 10, 10]               0
# Conv2dStaticSamePadding-355         [-1, 1392, 10, 10]         322,944
#      BatchNorm2d-356         [-1, 1392, 10, 10]           2,784
# MemoryEfficientSwish-357         [-1, 1392, 10, 10]               0
#        ZeroPad2d-358         [-1, 1392, 14, 14]               0
# Conv2dStaticSamePadding-359         [-1, 1392, 10, 10]          34,800
#      BatchNorm2d-360         [-1, 1392, 10, 10]           2,784
# MemoryEfficientSwish-361         [-1, 1392, 10, 10]               0
#         Identity-362           [-1, 1392, 1, 1]               0
# Conv2dStaticSamePadding-363             [-1, 58, 1, 1]          80,794
# MemoryEfficientSwish-364             [-1, 58, 1, 1]               0
#         Identity-365             [-1, 58, 1, 1]               0
# Conv2dStaticSamePadding-366           [-1, 1392, 1, 1]          82,128
#         Identity-367         [-1, 1392, 10, 10]               0
# Conv2dStaticSamePadding-368          [-1, 232, 10, 10]         322,944
#      BatchNorm2d-369          [-1, 232, 10, 10]             464
#      MBConvBlock-370          [-1, 232, 10, 10]               0
#         Identity-371          [-1, 232, 10, 10]               0
# Conv2dStaticSamePadding-372         [-1, 1392, 10, 10]         322,944
#      BatchNorm2d-373         [-1, 1392, 10, 10]           2,784
# MemoryEfficientSwish-374         [-1, 1392, 10, 10]               0
#        ZeroPad2d-375         [-1, 1392, 14, 14]               0
# Conv2dStaticSamePadding-376         [-1, 1392, 10, 10]          34,800
#      BatchNorm2d-377         [-1, 1392, 10, 10]           2,784
# MemoryEfficientSwish-378         [-1, 1392, 10, 10]               0
#         Identity-379           [-1, 1392, 1, 1]               0
# Conv2dStaticSamePadding-380             [-1, 58, 1, 1]          80,794
# MemoryEfficientSwish-381             [-1, 58, 1, 1]               0
#         Identity-382             [-1, 58, 1, 1]               0
# Conv2dStaticSamePadding-383           [-1, 1392, 1, 1]          82,128
#         Identity-384         [-1, 1392, 10, 10]               0
# Conv2dStaticSamePadding-385          [-1, 232, 10, 10]         322,944
#      BatchNorm2d-386          [-1, 232, 10, 10]             464
#      MBConvBlock-387          [-1, 232, 10, 10]               0
#         Identity-388          [-1, 232, 10, 10]               0
# Conv2dStaticSamePadding-389         [-1, 1392, 10, 10]         322,944
#      BatchNorm2d-390         [-1, 1392, 10, 10]           2,784
# MemoryEfficientSwish-391         [-1, 1392, 10, 10]               0
#        ZeroPad2d-392         [-1, 1392, 14, 14]               0
# Conv2dStaticSamePadding-393         [-1, 1392, 10, 10]          34,800
#      BatchNorm2d-394         [-1, 1392, 10, 10]           2,784
# MemoryEfficientSwish-395         [-1, 1392, 10, 10]               0
#         Identity-396           [-1, 1392, 1, 1]               0
# Conv2dStaticSamePadding-397             [-1, 58, 1, 1]          80,794
# MemoryEfficientSwish-398             [-1, 58, 1, 1]               0
#         Identity-399             [-1, 58, 1, 1]               0
# Conv2dStaticSamePadding-400           [-1, 1392, 1, 1]          82,128
#         Identity-401         [-1, 1392, 10, 10]               0
# Conv2dStaticSamePadding-402          [-1, 232, 10, 10]         322,944
#      BatchNorm2d-403          [-1, 232, 10, 10]             464
#      MBConvBlock-404          [-1, 232, 10, 10]               0
#         Identity-405          [-1, 232, 10, 10]               0
# Conv2dStaticSamePadding-406         [-1, 1392, 10, 10]         322,944
#      BatchNorm2d-407         [-1, 1392, 10, 10]           2,784
# MemoryEfficientSwish-408         [-1, 1392, 10, 10]               0
#        ZeroPad2d-409         [-1, 1392, 12, 12]               0
# Conv2dStaticSamePadding-410         [-1, 1392, 10, 10]          12,528
#      BatchNorm2d-411         [-1, 1392, 10, 10]           2,784
# MemoryEfficientSwish-412         [-1, 1392, 10, 10]               0
#         Identity-413           [-1, 1392, 1, 1]               0
# Conv2dStaticSamePadding-414             [-1, 58, 1, 1]          80,794
# MemoryEfficientSwish-415             [-1, 58, 1, 1]               0
#         Identity-416             [-1, 58, 1, 1]               0
# Conv2dStaticSamePadding-417           [-1, 1392, 1, 1]          82,128
#         Identity-418         [-1, 1392, 10, 10]               0
# Conv2dStaticSamePadding-419          [-1, 384, 10, 10]         534,528
#      BatchNorm2d-420          [-1, 384, 10, 10]             768
#      MBConvBlock-421          [-1, 384, 10, 10]               0
#         Identity-422          [-1, 384, 10, 10]               0
# Conv2dStaticSamePadding-423         [-1, 2304, 10, 10]         884,736
#      BatchNorm2d-424         [-1, 2304, 10, 10]           4,608
# MemoryEfficientSwish-425         [-1, 2304, 10, 10]               0
#        ZeroPad2d-426         [-1, 2304, 12, 12]               0
# Conv2dStaticSamePadding-427         [-1, 2304, 10, 10]          20,736
#      BatchNorm2d-428         [-1, 2304, 10, 10]           4,608
# MemoryEfficientSwish-429         [-1, 2304, 10, 10]               0
#         Identity-430           [-1, 2304, 1, 1]               0
# Conv2dStaticSamePadding-431             [-1, 96, 1, 1]         221,280
# MemoryEfficientSwish-432             [-1, 96, 1, 1]               0
#         Identity-433             [-1, 96, 1, 1]               0
# Conv2dStaticSamePadding-434           [-1, 2304, 1, 1]         223,488
#         Identity-435         [-1, 2304, 10, 10]               0
# Conv2dStaticSamePadding-436          [-1, 384, 10, 10]         884,736
#      BatchNorm2d-437          [-1, 384, 10, 10]             768
#      MBConvBlock-438          [-1, 384, 10, 10]               0
#         Identity-439          [-1, 384, 10, 10]               0
# Conv2dStaticSamePadding-440         [-1, 1536, 10, 10]         589,824
#      BatchNorm2d-441         [-1, 1536, 10, 10]           3,072
# MemoryEfficientSwish-442         [-1, 1536, 10, 10]               0
# AdaptiveAvgPool2d-443           [-1, 1536, 1, 1]               0
#          Dropout-444                 [-1, 1536]               0
#           Linear-445                   [-1, 22]          33,814
# ================================================================
# Total params: 10,730,046
# Trainable params: 10,730,046
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 1.03
# Forward/backward pass size (MB): 745.57
# Params size (MB): 40.93
# Estimated Total Size (MB): 787.54
# ----------------------------------------------------------------
